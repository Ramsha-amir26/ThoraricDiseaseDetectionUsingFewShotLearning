# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramsha-amir26/ThoraricDiseaseDetectionUsingFewShotLearning/blob/main/ResultsVisualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_vgg_2way_3shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_3shot_testing_group1.csv"
file_resnet_2way_3shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_3shot_testing_group1.csv"
file_densenet_2way_3shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_3shot_testing_group1.csv"

df_vgg_2way_3shot = pd.read_csv(file_vgg_2way_3shot)
df_resnet_2way_3shot = pd.read_csv(file_resnet_2way_3shot)
df_densenet_2way_3shot = pd.read_csv(file_densenet_2way_3shot)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot Accuracy on the first subplot (ax1)
ax1.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_3shot['Accuracy'], label='VGG19 Accuracy', color='blue')
ax1.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_3shot['Accuracy'], label='ResNet50 Accuracy', color='green')
ax1.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_3shot['Accuracy'], label='DenseNet121 Accuracy', color='red')
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Episodes (2-Way 3-Shot)')
ax1.legend(loc='upper left')

# Plot Loss on the second subplot (ax2)
ax2.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_3shot['Loss'], label='VGG19 Loss', color='blue', linestyle='--')
ax2.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_3shot['Loss'], label='ResNet50 Loss', color='green', linestyle='--')
ax2.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_3shot['Loss'], label='DenseNet121 Loss', color='red', linestyle='--')
ax2.set_xlabel('Episodes')
ax2.set_ylabel('Loss')
ax2.set_title('Loss vs Episodes (2-Way 3-Shot)')
ax2.legend(loc='upper left')

# Adjust the layout to make sure everything fits
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_vgg_2way_5shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_5shot_testing_group1.csv"
file_resnet_2way_5shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_5shot_testing_group1.csv"
file_densenet_2way_5shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_5shot_testing_group1.csv"

df_vgg_2way_5shot = pd.read_csv(file_vgg_2way_5shot)
df_resnet_2way_5shot = pd.read_csv(file_resnet_2way_5shot)
df_densenet_2way_5shot = pd.read_csv(file_densenet_2way_5shot)

# %%
import matplotlib.pyplot as plt

# Create a figure with 2 subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot Accuracy on the first subplot (ax1)
ax1.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_5shot['Accuracy'], label='VGG19 Accuracy', color='blue')
ax1.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_5shot['Accuracy'], label='ResNet50 Accuracy', color='green')
ax1.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_5shot['Accuracy'], label='DenseNet121 Accuracy', color='red')
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Episodes (2-Way 5-Shot)')
ax1.legend(loc='upper left')

# Plot Loss on the second subplot (ax2)
ax2.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_5shot['Loss'], label='VGG19 Loss', color='blue', linestyle='--')
ax2.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_5shot['Loss'], label='ResNet50 Loss', color='green', linestyle='--')
ax2.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_5shot['Loss'], label='DenseNet121 Loss', color='red', linestyle='--')
ax2.set_xlabel('Episodes')
ax2.set_ylabel('Loss')
ax2.set_title('Loss vs Episodes (2-Way 5-Shot)')
ax2.legend(loc='upper left')

# Adjust the layout to make sure everything fits
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_vgg_2way_3shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_3shot_testing_group2.csv"
file_resnet_2way_3shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_3shot_testing_group2.csv"
file_densenet_2way_3shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_3shot_testing_group2.csv"

df_vgg_2way_3shot = pd.read_csv(file_vgg_2way_3shot)
df_resnet_2way_3shot = pd.read_csv(file_resnet_2way_3shot)
df_densenet_2way_3shot = pd.read_csv(file_densenet_2way_3shot)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot Accuracy on the first subplot (ax1)
ax1.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_3shot['Accuracy'], label='VGG19 Accuracy', color='blue')
ax1.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_3shot['Accuracy'], label='ResNet50 Accuracy', color='green')
ax1.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_3shot['Accuracy'], label='DenseNet121 Accuracy', color='red')
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Episodes (2-Way 3-Shot)')
ax1.legend(loc='upper left')

# Plot Loss on the second subplot (ax2)
ax2.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_3shot['Loss'], label='VGG19 Loss', color='blue', linestyle='--')
ax2.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_3shot['Loss'], label='ResNet50 Loss', color='green', linestyle='--')
ax2.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_3shot['Loss'], label='DenseNet121 Loss', color='red', linestyle='--')
ax2.set_xlabel('Episodes')
ax2.set_ylabel('Loss')
ax2.set_title('Loss vs Episodes (2-Way 3-Shot)')
ax2.legend(loc='upper left')

# Adjust the layout to make sure everything fits
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_vgg_2way_5shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_5shot_testing_group2.csv"
file_resnet_2way_5shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_5shot_testing_group2.csv"
file_densenet_2way_5shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_5shot_testing_group2.csv"

df_vgg_2way_5shot = pd.read_csv(file_vgg_2way_5shot)
df_resnet_2way_5shot = pd.read_csv(file_resnet_2way_5shot)
df_densenet_2way_5shot = pd.read_csv(file_densenet_2way_5shot)

# %%
import matplotlib.pyplot as plt

# Create a figure with 2 subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot Accuracy on the first subplot (ax1)
ax1.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_5shot['Accuracy'], label='VGG19 Accuracy', color='blue')
ax1.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_5shot['Accuracy'], label='ResNet50 Accuracy', color='green')
ax1.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_5shot['Accuracy'], label='DenseNet121 Accuracy', color='red')
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Episodes (2-Way 5-Shot)')
ax1.legend(loc='upper left')

# Plot Loss on the second subplot (ax2)
ax2.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_5shot['Loss'], label='VGG19 Loss', color='blue', linestyle='--')
ax2.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_5shot['Loss'], label='ResNet50 Loss', color='green', linestyle='--')
ax2.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_5shot['Loss'], label='DenseNet121 Loss', color='red', linestyle='--')
ax2.set_xlabel('Episodes')
ax2.set_ylabel('Loss')
ax2.set_title('Loss vs Episodes (2-Way 5-Shot)')
ax2.legend(loc='upper left')

# Adjust the layout to make sure everything fits
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_vgg_2way_5shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_3shot_testing_group3.csv"
file_resnet_2way_5shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_3shot_testing_group3.csv"
file_densenet_2way_5shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_3shot_testing_group3.csv"

df_vgg_2way_5shot = pd.read_csv(file_vgg_2way_5shot)
df_resnet_2way_5shot = pd.read_csv(file_resnet_2way_5shot)
df_densenet_2way_5shot = pd.read_csv(file_densenet_2way_5shot)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot Accuracy on the first subplot (ax1)
ax1.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_3shot['Accuracy'], label='VGG19 Accuracy', color='blue')
ax1.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_3shot['Accuracy'], label='ResNet50 Accuracy', color='green')
ax1.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_3shot['Accuracy'], label='DenseNet121 Accuracy', color='red')
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Episodes (2-Way 3-Shot)')
ax1.legend(loc='upper left')

# Plot Loss on the second subplot (ax2)
ax2.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_3shot['Loss'], label='VGG19 Loss', color='blue', linestyle='--')
ax2.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_3shot['Loss'], label='ResNet50 Loss', color='green', linestyle='--')
ax2.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_3shot['Loss'], label='DenseNet121 Loss', color='red', linestyle='--')
ax2.set_xlabel('Episodes')
ax2.set_ylabel('Loss')
ax2.set_title('Loss vs Episodes (2-Way 3-Shot)')
ax2.legend(loc='upper left')

# Adjust the layout to make sure everything fits
plt.tight_layout()

# Show the plot
plt.show()

# %%
file_vgg_2way_5shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_5shot_testing_group3.csv"
file_resnet_2way_5shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_5shot_testing_group3.csv"
file_densenet_2way_5shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_5shot_testing_group3.csv"

df_vgg_2way_5shot = pd.read_csv(file_vgg_2way_5shot)
df_resnet_2way_5shot = pd.read_csv(file_resnet_2way_5shot)
df_densenet_2way_5shot = pd.read_csv(file_densenet_2way_5shot)

# %%
import matplotlib.pyplot as plt

# Create a figure with 2 subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))

# Plot Accuracy on the first subplot (ax1)
ax1.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_5shot['Accuracy'], label='VGG19 Accuracy', color='blue')
ax1.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_5shot['Accuracy'], label='ResNet50 Accuracy', color='green')
ax1.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_5shot['Accuracy'], label='DenseNet121 Accuracy', color='red')
ax1.set_xlabel('Episodes')
ax1.set_ylabel('Accuracy')
ax1.set_title('Accuracy vs Episodes (2-Way 5-Shot)')
ax1.legend(loc='upper left')

# Plot Loss on the second subplot (ax2)
ax2.plot(df_vgg_2way_3shot['Episode'], df_vgg_2way_5shot['Loss'], label='VGG19 Loss', color='blue', linestyle='--')
ax2.plot(df_resnet_2way_3shot['Episode'], df_resnet_2way_5shot['Loss'], label='ResNet50 Loss', color='green', linestyle='--')
ax2.plot(df_densenet_2way_3shot['Episode'], df_densenet_2way_5shot['Loss'], label='DenseNet121 Loss', color='red', linestyle='--')
ax2.set_xlabel('Episodes')
ax2.set_ylabel('Loss')
ax2.set_title('Loss vs Episodes (2-Way 5-Shot)')
ax2.legend(loc='upper left')

# Adjust the layout to make sure everything fits
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.colors as mcolors

def plot_metrics_from_csv(*csv_files, figsize=(12, 7)):
    """
    Plots precision, recall, and F1 score for multiple models from CSV files.

    :param csv_files: Variable length argument list of CSV file paths.
    :param figsize: Tuple specifying the size of the figure, default is (12, 7).
    :return: None, displays the plot.
    """
    metrics = ['Precision', 'Recall', 'F1 Score']
    data = {metric: [] for metric in metrics}
    models = []

    for csv_file in csv_files:
        model_name = csv_file.split('/')[-2]  # Assuming model name is in the directory name
        models.append(model_name)
        df = pd.read_csv(csv_file)

        def compute_metrics(df):
            y_true = df['True Class'].values
            y_pred = df['Pred Class'].values
            return (
                precision_score(y_true, y_pred, average='weighted'),
                recall_score(y_true, y_pred, average='weighted'),
                f1_score(y_true, y_pred, average='weighted')
            )

        precision, recall, f1 = compute_metrics(df)
        data['Precision'].append(precision)
        data['Recall'].append(recall)
        data['F1 Score'].append(f1)

    # Create the plot
    fig, ax = plt.subplots(figsize=figsize)

    x = range(len(models))
    width = 0.25

    for i, metric in enumerate(metrics):
        offset = width * i
        ax.bar([x + offset for x in range(len(models))], data[metric], width,
               label=metric)

    ax.set_ylabel('Score')
    ax.set_title('Comparison of Precision, Recall, and F1 Score Across Models')
    ax.set_xticks([r + width for r in range(len(models))])
    ax.set_xticklabels(models)
    ax.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Group 1 2 way 3 shot

# %%
file_vgg_2way_3shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_3shot_results_group1.csv"
file_resnet_2way_3shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_3shot_results_group1.csv"
file_densenet_2way_3shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_3shot_results_group1.csv"

plot_metrics_from_csv(file_vgg_2way_3shot, file_resnet_2way_3shot, file_densenet_2way_3shot)

# %%
file_vgg_2way_5shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2way_5shot_results_group1.csv"
file_resnet_2way_5shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2way_5shot_results_group1.csv"
file_densenet_2way_5shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2way_5shot_results_group1.csv"

plot_metrics_from_csv(file_vgg_2way_5shot, file_resnet_2way_5shot, file_densenet_2way_5shot)

# %% [markdown]
# ### Group 2

# %%
file_vgg_2way_3shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_3shot_results_group2.csv"
file_resnet_2way_3shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_3shot_results_group2.csv"
file_densenet_2way_3shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_3shot_results_group2.csv"

plot_metrics_from_csv(file_vgg_2way_3shot, file_resnet_2way_3shot, file_densenet_2way_3shot)

# %%
file_vgg_2way_5shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_5shot_results_group2.csv"
file_resnet_2way_5shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_5shot_results_group2.csv"
file_densenet_2way_5shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_5shot_results_group2.csv"


plot_metrics_from_csv(file_vgg_2way_5shot, file_resnet_2way_5shot, file_densenet_2way_5shot)

# %% [markdown]
# ### Group 3

# %%
file_vgg_2way_3shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_3shot_results_group3.csv"
file_resnet_2way_3shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_3shot_results_group3.csv"
file_densenet_2way_3shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_3shot_results_group3.csv"

plot_metrics_from_csv(file_vgg_2way_3shot, file_resnet_2way_3shot, file_densenet_2way_3shot)

# %%
file_vgg_2way_3shot = "/content/drive/My Drive/Colab_Results/VGG19/vgg_2_way_5shot_results_group3.csv"
file_resnet_2way_3shot = "/content/drive/My Drive/Colab_Results/RESNET50/resnet50_2_way_5shot_results_group3.csv"
file_densenet_2way_3shot = "/content/drive/My Drive/Colab_Results/DENSENET121/densenet121_2_way_5shot_results_group3.csv"

plot_metrics_from_csv(file_vgg_2way_5shot, file_resnet_2way_5shot, file_densenet_2way_5shot)
